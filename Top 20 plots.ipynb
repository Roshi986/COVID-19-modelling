# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import iplot, init_notebook_mode

# %%
grouped = pd.read_csv('grouped_julyCOVID.csv')

# %%
world = grouped.groupby("Country/Region")['Confirmed','Recovered','Deaths', 'Active'].sum().reset_index()
world.tail(10)
# Out:
# C:\Users\AMC\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#          Country/Region  Confirmed  Recovered   Deaths      Active
# 178      United Kingdom   27050848   127655.0  4043738  22879455.0
# 179             Uruguay      95960    73717.0     2491     19752.0
# 180          Uzbekistan     699707   435803.0     3062    260842.0
# 181           Venezuela     428802   161737.0     4252    262813.0
# 182             Vietnam      41121    33207.0        0      7914.0
# 183  West Bank and Gaza     244399    64876.0     1449    178074.0
# 184      Western Sahara        911      656.0       64       191.0
# 185               Yemen      68883    24619.0    18191     26073.0
# 186              Zambia     134423    86806.0     2785     44832.0
# 187            Zimbabwe      53611    12811.0      921     39879.0

# %%
### Find top 20 countries with maximum number of confirmed cases
top_20 = world.sort_values(by=['Confirmed'], ascending=False).head(20)
### Generate a Barplot
plt.figure(figsize=(12,10))
plot = sns.barplot(top_20['Confirmed'], top_20['Country/Region'])
for i,(value,name) in enumerate(zip(top_20['Confirmed'],top_20['Country/Region'])):
    plot.text(value,i-0.05,f'{value:,.0f}',size=10)
plt.show()

# %%
### Find top 20 countries with maximum number of deaths cases
top_20 = world.sort_values(by=['Deaths'], ascending=False).head(20)
### Generate a Barplot
plt.figure(figsize=(12,10))
plot = sns.barplot(top_20['Deaths'], top_20['Country/Region'])
for i,(value,name) in enumerate(zip(top_20['Deaths'],top_20['Country/Region'])):
    plot.text(value,i-0.05,f'{value:,.0f}',size=10)
plt.show()

# %%
### Find top 20 countries with maximum number of Recovered cases
top_20 = world.sort_values(by=['Recovered'], ascending=False).head(20)
### Generate a Barplot
plt.figure(figsize=(12,10))
plot = sns.barplot(top_20['Recovered'], top_20['Country/Region'])
for i,(value,name) in enumerate(zip(top_20['Recovered'],top_20['Country/Region'])):
    plot.text(value,i-0.05,f'{value:,.0f}',size=10)
plt.show()

# %%
### Find top 20 countries with maximum number of Active cases
top_20 = world.sort_values(by=['Active'], ascending=False).head(20)
### Generate a Barplot
plt.figure(figsize=(12,10))
plot = sns.barplot(top_20['Active'], top_20['Country/Region'])
for i,(value,name) in enumerate(zip(top_20['Active'],top_20['Country/Region'])):
    plot.text(value,i-0.05,f'{value:,.0f}',size=10)
plt.show()

# %%
top_3_confirmed = world.sort_values(by=['Confirmed'], ascending=False).head(3)

# %%
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.barplot(x="Country/Region", y="Confirmed", data=top_3_confirmed)
